# %% [markdown]
# ## Gráfico de Barras
# Vamos construir um gráfico de barras usando os dados do dataset Ebola.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Ebola.csv")

# %%
df.head()
# Out:
#       Countries             Type  Number_of_cases  Death
# 0        Guinea  comfirmed cases             3351   2083
# 1        Guinea   Probable cases              453    453
# 2  Sierra Leone  comfirmed cases             8704   3589
# 3  Sierra Leone   Probable cases              287    208
# 4  Sierra Leone  Suspected cases             5131    158

# %%
sns.barplot(x="Type", y="Death", hue="Countries", data=df, ci=None)
plt.title("Mortalidade do Ebola nos países Serra Leoa e Guiné")
plt.xlabel("Tipos de casos")
plt.ylabel("Número de mortes")
# Out:
# C:\Users\dudud\AppData\Local\Temp\ipykernel_2600\1280827720.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Type", y="Death", hue="Countries", data=df, ci=None)
# Text(0, 0.5, 'Número de mortes')

# %% [markdown]
# Vamos agora trabalhar com o dataset Migrants.csv. O primeiro passo é entender esse dataset, então vamos exibir alguns registros inicialmente.

# %%
df = pd.read_csv("Migrants.csv",encoding ='latin-1')

# %%
df.head(10)
# Out:
#    Web ID Region_of_Incident  Reported_Year  Number_Dead  \
# 0   44025   US-Mexico Border           2017         10.0
# 1   44026      Mediterranean           2017          NaN
# 2   44027      Mediterranean           2017          1.0
# 3   44017   US-Mexico Border           2017          1.0
# 4   44024   US-Mexico Border           2017          1.0
# 5   44023   US-Mexico Border           2017          1.0
# 6   44021   US-Mexico Border           2017          1.0
# 7   44022   US-Mexico Border           2017          1.0
# 8   44011      Mediterranean           2017          3.0
# 9   44012      Mediterranean           2017          1.0
#
#    Total_Dead_and_Missing
# 0                      10
# 1                       2
# 2                       1
# 3                       1
# 4                       1
# 5                       1
# 6                       1
# 7                       1
# 8                       3
# 9                       1

# %% [markdown]
# Vamos ver as diferentes regiões onde os incidentes aconteceram.

# %%
df['Region_of_Incident'].unique()
# Out:
# array(['US-Mexico Border', 'Mediterranean', 'Middle East', 'Europe',
#        'Central America', 'Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Southeast Asia', 'North Africa', 'Horn of Africa',
#        'North America', 'East Asia', 'South America'], dtype=object)

# %%
df2 = pd.crosstab(df['Region_of_Incident'], df['Reported_Year'], values=df['Total_Dead_and_Missing'], aggfunc=np.sum)
df2
# Out:
# Reported_Year         2014    2015    2016    2017
# Region_of_Incident
# Caribbean             73.0    68.0   105.0   156.0
# Central America      116.0   101.0   181.0    76.0
# East Asia              9.0    15.0     3.0     1.0
# Europe                20.0   136.0    62.0    90.0
# Horn of Africa       265.0   135.0   235.0   170.0
# Mediterranean       3283.0  3785.0  5143.0  3095.0
# Middle East           39.0    36.0   114.0   208.0
# North Africa          89.0   801.0  1382.0   467.0
# North America          NaN     NaN     NaN     1.0
# South America          NaN     2.0    32.0     NaN
# South Asia             2.0     NaN     NaN    21.0
# Southeast Asia       814.0   789.0   187.0   295.0
# Sub-Saharan Africa   268.0    74.0    92.0   387.0
# US-Mexico Border     307.0   339.0   396.0   356.0

# %% [markdown]
# Agora vamos criar um gráfico de barras mostrando o número de mortos e desaparecidos no ano de 2016.

# %%
plt.rcParams["figure.figsize"] = [10,8]
sns.set_context("notebook", font_scale=1.5, rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":12})
df2.plot(kind="bar",stacked=False)
plt.title("Migrantes mortos ou desaparecidos entre 2014 e 2016")
plt.ylabel("Mortos ou desaparecidos")
plt.xlabel("Região")
plt.show()
